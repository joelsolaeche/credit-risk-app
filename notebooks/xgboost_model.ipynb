# %% [markdown]
# # Xgboost model training

# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from lightgbm import LGBMClassifier
from sklearn.metrics import make_scorer
from sklearn.utils.class_weight import compute_class_weight
import os

# %%
#Loading data

#Defining BASE_PATH
BASE_PATH = os.getenv("/Users/carlos/Desktop/CURSOS/Anyone AI/Credit-Risk-App/dataset/", "/Users/carlos/Desktop/CURSOS/Anyone AI/Credit-Risk-App/dataset/")

train_file_path = os.path.join(BASE_PATH, "X_train_data.csv")
y_train_file_path = os.path.join(BASE_PATH, "y_train_data.csv")
val_file_path = os.path.join(BASE_PATH, "X_val_data.csv")
y_val_path = os.path.join(BASE_PATH, "y_val_data.csv")

train_df = pd.read_csv(train_file_path)

y_train_df = pd.read_csv(y_train_file_path)
y_train = y_train_df['TARGET_LABEL_BAD']
y_train = y_train.to_numpy()

val_df = pd.read_csv(val_file_path)

y_valid_df = pd.read_csv(y_val_path)
y_valid = y_valid_df['TARGET_LABEL_BAD']
y_valid = y_valid.to_numpy()

# %% [markdown]
# XGBoost incluye su propia clase para almacenar conjuntos de datos, llamada DMatrix.  Es una clase muy optimizada en cuanto a memoria y velocidad.  Por eso, convertir conjuntos de datos a este formato es un requisito para la API nativa de XGBoost.

# %% [markdown]
# ## XGBoost with default parameters

# %%
#Training a XGBoost model with default params

# Convert data to DMatrix format
dtrain = xgb.DMatrix(train_df, label=y_train)
dvalid = xgb.DMatrix(val_df, label=y_valid)

# Define parameters
params = {
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "eta": 0.1,
    "max_depth": 6,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "lambda": 1,
    "alpha": 0
}

# Train model
evals = [(dtrain, "train"), (dvalid, "valid")]
model = xgb.train(params, dtrain, num_boost_round=100, evals=evals, early_stopping_rounds=10)

# Predictions
y_pred_proba = model.predict(dvalid)
y_pred = (y_pred_proba > 0.5).astype(int)

# Performance Metrics
conf_matrix = confusion_matrix(y_valid, y_pred)
print("Confusion Matrix:\n", conf_matrix)
print("\nAccuracy:", accuracy_score(y_valid, y_pred))
print("\nClassification Report:\n", classification_report(y_valid, y_pred))
# Out:
# [0]	train-logloss:0.57025	valid-logloss:0.57770
# [1]	train-logloss:0.56766	valid-logloss:0.57599
# [2]	train-logloss:0.56556	valid-logloss:0.57466
# [3]	train-logloss:0.56358	valid-logloss:0.57344
# [4]	train-logloss:0.56166	valid-logloss:0.57255
# [5]	train-logloss:0.56003	valid-logloss:0.57173
# [6]	train-logloss:0.55860	valid-logloss:0.57105
# [7]	train-logloss:0.55714	valid-logloss:0.57029
# [8]	train-logloss:0.55590	valid-logloss:0.56975
# [9]	train-logloss:0.55449	valid-logloss:0.56905
# [10]	train-logloss:0.55330	valid-logloss:0.56846
# [11]	train-logloss:0.55215	valid-logloss:0.56811
# [12]	train-logloss:0.55114	valid-logloss:0.56763
# [13]	train-logloss:0.55012	valid-logloss:0.56718
# [14]	train-logloss:0.54903	valid-logloss:0.56652
# [15]	train-logloss:0.54824	valid-logloss:0.56646
# [16]	train-logloss:0.54747	valid-logloss:0.56601
# [17]	train-logloss:0.54658	valid-logloss:0.56584
# [18]	train-logloss:0.54572	valid-logloss:0.56553
# [19]	train-logloss:0.54482	valid-logloss:0.56558
# [20]	train-logloss:0.54414	valid-logloss:0.56519
# [21]	train-logloss:0.54342	valid-logloss:0.56515
# [22]	train-logloss:0.54280	valid-logloss:0.56501
# [23]	train-logloss:0.54188	valid-logloss:0.56476
# [24]	train-logloss:0.54121	valid-logloss:0.56461
# [25]	train-logloss:0.54053	valid-logloss:0.56445
# [26]	train-logloss:0.53975	valid-logloss:0.56416
# [27]	train-logloss:0.53878	valid-logloss:0.56366
# [28]	train-logloss:0.53796	valid-logloss:0.56333
# [29]	train-logloss:0.53714	valid-logloss:0.56311
# [30]	train-logloss:0.53665	valid-logloss:0.56292
# [31]	train-logloss:0.53598	valid-logloss:0.56272
# [32]	train-logloss:0.53539	valid-logloss:0.56261
# [33]	train-logloss:0.53484	valid-logloss:0.56238
# [34]	train-logloss:0.53429	valid-logloss:0.56224
# [35]	train-logloss:0.53369	valid-logloss:0.56220
# [36]	train-logloss:0.53299	valid-logloss:0.56197
# [37]	train-logloss:0.53239	valid-logloss:0.56179
# [38]	train-logloss:0.53165	valid-logloss:0.56182
# [39]	train-logloss:0.53117	valid-logloss:0.56178
# [40]	train-logloss:0.53075	valid-logloss:0.56183
# [41]	train-logloss:0.53003	valid-logloss:0.56169
# [42]	train-logloss:0.52967	valid-logloss:0.56160
# [43]	train-logloss:0.52915	valid-logloss:0.56157
# [44]	train-logloss:0.52871	valid-logloss:0.56143
# [45]	train-logloss:0.52835	valid-logloss:0.56148
# [46]	train-logloss:0.52792	valid-logloss:0.56141
# [47]	train-logloss:0.52751	valid-logloss:0.56132
# [48]	train-logloss:0.52679	valid-logloss:0.56133
# [49]	train-logloss:0.52627	valid-logloss:0.56118
# [50]	train-logloss:0.52568	valid-logloss:0.56112
# [51]	train-logloss:0.52513	valid-logloss:0.56116
# [52]	train-logloss:0.52482	valid-logloss:0.56114
# [53]	train-logloss:0.52435	valid-logloss:0.56098
# [54]	train-logloss:0.52391	valid-logloss:0.56097
# [55]	train-logloss:0.52340	valid-logloss:0.56098
# [56]	train-logloss:0.52295	valid-logloss:0.56088
# [57]	train-logloss:0.52245	valid-logloss:0.56085
# [58]	train-logloss:0.52205	valid-logloss:0.56071
# [59]	train-logloss:0.52167	valid-logloss:0.56065
# [60]	train-logloss:0.52114	valid-logloss:0.56055
# [61]	train-logloss:0.52052	valid-logloss:0.56025
# [62]	train-logloss:0.52009	valid-logloss:0.56015
# [63]	train-logloss:0.51982	valid-logloss:0.56015
# [64]	train-logloss:0.51928	valid-logloss:0.55987
# [65]	train-logloss:0.51873	valid-logloss:0.55975
# [66]	train-logloss:0.51825	valid-logloss:0.55978
# [67]	train-logloss:0.51791	valid-logloss:0.55971
# [68]	train-logloss:0.51741	valid-logloss:0.55966
# [69]	train-logloss:0.51696	valid-logloss:0.55961
# [70]	train-logloss:0.51643	valid-logloss:0.55948
# [71]	train-logloss:0.51604	valid-logloss:0.55949
# [72]	train-logloss:0.51555	valid-logloss:0.55943
# [73]	train-logloss:0.51520	valid-logloss:0.55940
# [74]	train-logloss:0.51475	valid-logloss:0.55939
# [75]	train-logloss:0.51420	valid-logloss:0.55929
# [76]	train-logloss:0.51374	valid-logloss:0.55921
# [77]	train-logloss:0.51333	valid-logloss:0.55911
# [78]	train-logloss:0.51304	valid-logloss:0.55907
# [79]	train-logloss:0.51240	valid-logloss:0.55912
# [80]	train-logloss:0.51202	valid-logloss:0.55897
# [81]	train-logloss:0.51153	valid-logloss:0.55894
# [82]	train-logloss:0.51126	valid-logloss:0.55893
# [83]	train-logloss:0.51082	valid-logloss:0.55881
# [84]	train-logloss:0.51046	valid-logloss:0.55868
# [85]	train-logloss:0.51012	valid-logloss:0.55861
# [86]	train-logloss:0.50972	valid-logloss:0.55852
# [87]	train-logloss:0.50934	valid-logloss:0.55861
# [88]	train-logloss:0.50904	valid-logloss:0.55864
# [89]	train-logloss:0.50870	valid-logloss:0.55868
# [90]	train-logloss:0.50837	valid-logloss:0.55870
# [91]	train-logloss:0.50793	valid-logloss:0.55867
# [92]	train-logloss:0.50748	valid-logloss:0.55857
# [93]	train-logloss:0.50714	valid-logloss:0.55862
# [94]	train-logloss:0.50683	valid-logloss:0.55850
# [95]	train-logloss:0.50656	valid-logloss:0.55849
# [96]	train-logloss:0.50608	valid-logloss:0.55851
# [97]	train-logloss:0.50554	valid-logloss:0.55854
# [98]	train-logloss:0.50527	valid-logloss:0.55841
# [99]	train-logloss:0.50488	valid-logloss:0.55838
# Confusion Matrix:
#  [[7278   58]
#  [2612   52]]
#
# Accuracy: 0.733
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85      7336
#            1       0.47      0.02      0.04      2664
#
#     accuracy                           0.73     10000
#    macro avg       0.60      0.51      0.44     10000
# weighted avg       0.67      0.73      0.63     10000

# %%
# Hyperparameter tuning

param_grid = {
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05, 0.1],
    "n_estimators": [50, 100, 200],
    "subsample": [0.6, 0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]  
}

xgb_clf = xgb.XGBClassifier(objective="binary:logistic", eval_metric="logloss")

grid_search = GridSearchCV(xgb_clf, param_grid, scoring="accuracy", cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42), n_jobs=-1, verbose=1)
grid_search.fit(train_df, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8}

# %%
# Define parameters based on parameter optimization
params = {
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "eta": 0.05,
    "max_depth": 7,
    "subsample": 0.8,
    "colsample_bytree": 1.0,
    "lambda": 1,
    "alpha": 0
}

# Train model
evals = [(dtrain, "train"), (dvalid, "valid")]
model = xgb.train(params, dtrain, num_boost_round=100, evals=evals, early_stopping_rounds=10)

# Predictions
y_pred_proba = model.predict(dvalid)
y_pred = (y_pred_proba > 0.5).astype(int)

# Performance Metrics
conf_matrix = confusion_matrix(y_valid, y_pred)
print("Confusion Matrix:\n", conf_matrix)
print("\nAccuracy:", accuracy_score(y_valid, y_pred))
print("\nClassification Report:\n", classification_report(y_valid, y_pred))
# Out:
# [0]	train-logloss:0.57128	valid-logloss:0.57874
# [1]	train-logloss:0.56951	valid-logloss:0.57767
# [2]	train-logloss:0.56781	valid-logloss:0.57654
# [3]	train-logloss:0.56616	valid-logloss:0.57554
# [4]	train-logloss:0.56462	valid-logloss:0.57475
# [5]	train-logloss:0.56319	valid-logloss:0.57397
# [6]	train-logloss:0.56189	valid-logloss:0.57333
# [7]	train-logloss:0.56062	valid-logloss:0.57272
# [8]	train-logloss:0.55946	valid-logloss:0.57226
# [9]	train-logloss:0.55828	valid-logloss:0.57167
# [10]	train-logloss:0.55720	valid-logloss:0.57114
# [11]	train-logloss:0.55601	valid-logloss:0.57070
# [12]	train-logloss:0.55507	valid-logloss:0.57030
# [13]	train-logloss:0.55406	valid-logloss:0.56993
# [14]	train-logloss:0.55317	valid-logloss:0.56958
# [15]	train-logloss:0.55226	valid-logloss:0.56925
# [16]	train-logloss:0.55130	valid-logloss:0.56887
# [17]	train-logloss:0.55024	valid-logloss:0.56852
# [18]	train-logloss:0.54933	valid-logloss:0.56819
# [19]	train-logloss:0.54854	valid-logloss:0.56793
# [20]	train-logloss:0.54765	valid-logloss:0.56772
# [21]	train-logloss:0.54697	valid-logloss:0.56742
# [22]	train-logloss:0.54617	valid-logloss:0.56726
# [23]	train-logloss:0.54535	valid-logloss:0.56706
# [24]	train-logloss:0.54472	valid-logloss:0.56693
# [25]	train-logloss:0.54399	valid-logloss:0.56682
# [26]	train-logloss:0.54326	valid-logloss:0.56663
# [27]	train-logloss:0.54253	valid-logloss:0.56640
# [28]	train-logloss:0.54165	valid-logloss:0.56608
# [29]	train-logloss:0.54100	valid-logloss:0.56588
# [30]	train-logloss:0.54033	valid-logloss:0.56560
# [31]	train-logloss:0.53966	valid-logloss:0.56545
# [32]	train-logloss:0.53914	valid-logloss:0.56528
# [33]	train-logloss:0.53854	valid-logloss:0.56504
# [34]	train-logloss:0.53805	valid-logloss:0.56487
# [35]	train-logloss:0.53734	valid-logloss:0.56471
# [36]	train-logloss:0.53690	valid-logloss:0.56439
# [37]	train-logloss:0.53630	valid-logloss:0.56417
# [38]	train-logloss:0.53580	valid-logloss:0.56407
# [39]	train-logloss:0.53533	valid-logloss:0.56398
# [40]	train-logloss:0.53471	valid-logloss:0.56391
# [41]	train-logloss:0.53411	valid-logloss:0.56376
# [42]	train-logloss:0.53358	valid-logloss:0.56354
# [43]	train-logloss:0.53301	valid-logloss:0.56341
# [44]	train-logloss:0.53265	valid-logloss:0.56331
# [45]	train-logloss:0.53230	valid-logloss:0.56323
# [46]	train-logloss:0.53167	valid-logloss:0.56323
# [47]	train-logloss:0.53116	valid-logloss:0.56310
# [48]	train-logloss:0.53053	valid-logloss:0.56303
# [49]	train-logloss:0.53013	valid-logloss:0.56293
# [50]	train-logloss:0.52954	valid-logloss:0.56274
# [51]	train-logloss:0.52904	valid-logloss:0.56266
# [52]	train-logloss:0.52861	valid-logloss:0.56252
# [53]	train-logloss:0.52819	valid-logloss:0.56249
# [54]	train-logloss:0.52784	valid-logloss:0.56241
# [55]	train-logloss:0.52740	valid-logloss:0.56234
# [56]	train-logloss:0.52710	valid-logloss:0.56226
# [57]	train-logloss:0.52674	valid-logloss:0.56216
# [58]	train-logloss:0.52641	valid-logloss:0.56210
# [59]	train-logloss:0.52590	valid-logloss:0.56207
# [60]	train-logloss:0.52549	valid-logloss:0.56200
# [61]	train-logloss:0.52497	valid-logloss:0.56185
# [62]	train-logloss:0.52464	valid-logloss:0.56169
# [63]	train-logloss:0.52408	valid-logloss:0.56159
# [64]	train-logloss:0.52361	valid-logloss:0.56153
# [65]	train-logloss:0.52329	valid-logloss:0.56151
# [66]	train-logloss:0.52294	valid-logloss:0.56140
# [67]	train-logloss:0.52244	valid-logloss:0.56129
# [68]	train-logloss:0.52194	valid-logloss:0.56119
# [69]	train-logloss:0.52164	valid-logloss:0.56114
# [70]	train-logloss:0.52130	valid-logloss:0.56114
# [71]	train-logloss:0.52091	valid-logloss:0.56102
# [72]	train-logloss:0.52045	valid-logloss:0.56093
# [73]	train-logloss:0.51991	valid-logloss:0.56080
# [74]	train-logloss:0.51963	valid-logloss:0.56073
# [75]	train-logloss:0.51921	valid-logloss:0.56068
# [76]	train-logloss:0.51880	valid-logloss:0.56062
# [77]	train-logloss:0.51848	valid-logloss:0.56050
# [78]	train-logloss:0.51811	valid-logloss:0.56046
# [79]	train-logloss:0.51765	valid-logloss:0.56043
# [80]	train-logloss:0.51723	valid-logloss:0.56028
# [81]	train-logloss:0.51690	valid-logloss:0.56024
# [82]	train-logloss:0.51662	valid-logloss:0.56016
# [83]	train-logloss:0.51619	valid-logloss:0.56010
# [84]	train-logloss:0.51585	valid-logloss:0.55998
# [85]	train-logloss:0.51549	valid-logloss:0.55991
# [86]	train-logloss:0.51521	valid-logloss:0.55981
# [87]	train-logloss:0.51484	valid-logloss:0.55985
# [88]	train-logloss:0.51455	valid-logloss:0.55990
# [89]	train-logloss:0.51426	valid-logloss:0.55987
# [90]	train-logloss:0.51398	valid-logloss:0.55990
# [91]	train-logloss:0.51361	valid-logloss:0.55985
# [92]	train-logloss:0.51323	valid-logloss:0.55984
# [93]	train-logloss:0.51293	valid-logloss:0.55980
# [94]	train-logloss:0.51263	valid-logloss:0.55970
# [95]	train-logloss:0.51237	valid-logloss:0.55961
# [96]	train-logloss:0.51194	valid-logloss:0.55959
# [97]	train-logloss:0.51140	valid-logloss:0.55948
# [98]	train-logloss:0.51115	valid-logloss:0.55940
# [99]	train-logloss:0.51081	valid-logloss:0.55937
# Confusion Matrix:
#  [[7318   18]
#  [2643   21]]
#
# Accuracy: 0.7339
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85      7336
#            1       0.54      0.01      0.02      2664
#
#     accuracy                           0.73     10000
#    macro avg       0.64      0.50      0.43     10000
# weighted avg       0.68      0.73      0.62     10000

# %%
# Get feature importance by gain
importance = model.get_score(importance_type="gain")
importance_df = pd.DataFrame(importance.items(), columns=["Feature", "Gain"]).sort_values(by="Gain", ascending=False)

print(importance_df.head(20))
# Out:
#                     Feature       Gain
# 135     OCCUPATION_TYPE_1.0  24.007029
# 5    FLAG_RESIDENCIAL_PHONE  19.475811
# 70         PAYMENT_DAY_25.0  16.645630
# 72       MARITAL_STATUS_1.0  15.721720
# 187                AGE_63.0  11.813228
# 142                AGE_18.0  11.207093
# 144                AGE_20.0  10.865468
# 154                AGE_30.0  10.059038
# 127     PROFESSION_CODE_8.0   9.959561
# 145                AGE_21.0   9.810191
# 195                AGE_71.0   9.788873
# 181                AGE_57.0   9.709737
# 198                AGE_78.0   9.684025
# 190                AGE_66.0   9.646227
# 90       RESIDENCE_TYPE_3.0   9.358445
# 192                AGE_68.0   9.228590
# 77       MARITAL_STATUS_6.0   9.227916
# 183                AGE_59.0   9.175991
# 182                AGE_58.0   9.065054
# 194                AGE_70.0   9.003184

# %% [markdown]
# ## Training XGBoost with imbalanced data strategy

# %%
# XGBoost model computing class weights for handling class imbalance
# First a model training using default param values
xgb_model = xgb.XGBClassifier(eval_metric='mlogloss', random_state=42)

# Fit the model
xgb_model.fit(train_df, y_train)

# Evaluate initial performance on validation set
y_pred = xgb_model.predict(val_df)
y_pred_prob = xgb_model.predict_proba(val_df)[:, 1]

# Metrics
print("Classification Report:")
print(classification_report(y_valid, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_valid, y_pred_prob))
print("Confusion Matrix:")
print(confusion_matrix(y_valid, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84      7336
#            1       0.43      0.08      0.13      2664
#
#     accuracy                           0.73     10000
#    macro avg       0.58      0.52      0.48     10000
# weighted avg       0.66      0.73      0.65     10000
#
# ROC-AUC Score: 0.6301169455988159
# Confusion Matrix:
# [[7062  274]
#  [2461  203]]

# %%
# Defining hyperparameters and  balancing dataset.

# Compute class weights to adjust scale_pos_weight
class_weights = compute_class_weight('balanced', classes=np.array([0, 1]), y=y_train)
scale_pos_weight = class_weights[1] / class_weights[0]  # Calculate scale_pos_weight

# Set up XGBoost model with hyperparameter tuning
params = {
    'scale_pos_weight': [scale_pos_weight],  # Use the computed scale_pos_weight
    'max_depth': [3, 5, 7],  # Example of tuning max_depth
    'learning_rate': [0.01, 0.05, 0.1],  # Learning rate
    'n_estimators': [100, 200],  # Number of estimators
    'subsample': [0.8, 1.0],  # Fraction of samples used for each tree
    'colsample_bytree': [0.8, 1.0]  # Fraction of features used for each tree
}

# Perform GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=xgb.XGBClassifier(eval_metric='mlogloss', random_state=42),
    param_grid=params,
    scoring=make_scorer(roc_auc_score),  # Scoring by ROC AUC
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    verbose=2,
    n_jobs=-1
)

# %%
# Fit the model with cross-validation and grid search
grid_search.fit(train_df, y_train)

# Best parameters and best score from the grid search
print("Best parameters:", grid_search.best_params_)
print("Best ROC-AUC score:", grid_search.best_score_)

# Step 4: Evaluate best model on validation set
best_model = grid_search.best_estimator_

# Predict on the validation set
y_pred_best = best_model.predict(val_df)
y_pred_prob_best = best_model.predict_proba(val_df)[:, 1]

# Metrics
print("Classification Report for Best Model:")
print(classification_report(y_valid, y_pred_best))
print("ROC-AUC Score for Best Model:", roc_auc_score(y_valid, y_pred_prob_best))
print("Confusion Matrix for Best Model:")
print(confusion_matrix(y_valid, y_pred_best))
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   6.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=100, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=7, n_estimators=200, scale_pos_weight=2.8546786161703768, subsample=1.0; total time=   3.1s
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'scale_pos_weight': np.float64(2.8546786161703768), 'subsample': 0.8}
# Best ROC-AUC score: 0.5930332295232862
# Classification Report for Best Model:
#               precision    recall  f1-score   support
#
#            0       0.80      0.58      0.67      7336
#            1       0.34      0.61      0.44      2664
#
#     accuracy                           0.58     10000
#    macro avg       0.57      0.59      0.55     10000
# weighted avg       0.68      0.58      0.61     10000
#
# ROC-AUC Score for Best Model: 0.6305510885067183
# Confusion Matrix for Best Model:
# [[4219 3117]
#  [1045 1619]]

# %%
# Feature Importance using Gain
importance = best_model.get_booster().get_score(importance_type="gain")

# Convert to DataFrame for better visualization
importance_df = pd.DataFrame(importance.items(), columns=["Feature", "Gain"])
importance_df = importance_df.sort_values(by="Gain", ascending=False)

# Print feature importance
print("\nFeature Importance (Gain):")
print(importance_df.head(40))
# Out:
# Feature Importance (Gain):
#                          Feature       Gain
# 122          OCCUPATION_TYPE_1.0  87.293053
# 64            MARITAL_STATUS_1.0  71.281769
# 63              PAYMENT_DAY_25.0  63.121243
# 5         FLAG_RESIDENCIAL_PHONE  50.562473
# 60              PAYMENT_DAY_10.0  42.450478
# 67            MARITAL_STATUS_4.0  36.159863
# 167                     AGE_63.0  32.977535
# 80            RESIDENCE_TYPE_1.0  28.239454
# 15       FLAG_PROFESSIONAL_PHONE  25.816042
# 142                     AGE_31.0  25.569647
# 65            MARITAL_STATUS_2.0  24.818583
# 79               NACIONALITY_1.0  24.803543
# 129                     AGE_18.0  24.414759
# 13                    QUANT_CARS  24.050468
# 155                     AGE_48.0  23.812122
# 59               PAYMENT_DAY_5.0  23.791893
# 1                            SEX  23.218260
# 110   QUANT_BANKING_ACCOUNTS_1.0  23.143536
# 158                     AGE_53.0  22.792255
# 159                     AGE_55.0  22.432432
# 49          RESIDENCIAL_STATE_PB  22.306227
# 62              PAYMENT_DAY_20.0  22.240162
# 131                     AGE_20.0  22.118176
# 163                     AGE_59.0  21.613642
# 166                     AGE_62.0  21.541002
# 69            MARITAL_STATUS_6.0  21.531954
# 141                     AGE_30.0  21.337709
# 6    RESIDENCIAL_PHONE_AREA_CODE  20.932344
# 11               FLAG_MASTERCARD  20.783243
# 4            RESIDENCIAL_BOROUGH  20.766434
# 81            RESIDENCE_TYPE_2.0  19.886391
# 104     MONTHS_IN_RESIDENCE_35.0  19.687029
# 17             RESIDENCIAL_ZIP_3  19.511227
# 3               RESIDENCIAL_CITY  19.500465
# 7                     FLAG_EMAIL  19.466854
# 170                     AGE_66.0  19.429995
# 161                     AGE_57.0  19.382580
# 173                     AGE_69.0  19.299725
# 171                     AGE_67.0  19.247358
# 55          RESIDENCIAL_STATE_SC  18.965530
